# %%
import pandas as pd
import numpy as np
from docx.enum.style import WD_STYLE_TYPE
import docx
import datetime
import calendar
import inflect
import random
from docx.shared import Inches, Pt
import openai
# import openai_secret_manager
import os
import requests
import json
import pandas as pd
import tiktoken

# %%
import os


# Now import required packages

import docx
from docx import Document
from docx.oxml.ns import qn
from docx.oxml import OxmlElement
from docx.shared import RGBColor

# %%
doc = docx.Document()

# %%
df = pd.read_csv('list_values.csv')

# %%
df = df.iloc[:,1:]

# %%
for i,u in zip(df['Keys'],df['Values']):
    print(i,u)

# %%
null_hypotheses = 'Null Hypothesis'
alternative_hypotheses = 'Alternative Hypothesis'
procedures = 'Procedures'
process_withdrawal = 'Process Withdrawal'
ethical_considerations = 'Ethical Considerations'
number_patients = 'number of patients'
duration = 'Duration'
disease = 'Disease'
detail = 'Details'
initial_version = 'Initial Version'

# %%
once = False
once1 = False
once2 = False
once3 = False
once4 = False
background = ''
for i  in df.iterrows():
    key = i[1][0]
    val = i[1][1]
    key = key.replace('_',' ')
    
    if isinstance(val,list):
        pass

    if 'author' in key:
        if once == False:
            author = val
            once = True

    if 'title' in key:
        if once1 == False:
            research_title= val
            once1 = True
            
    if 'cellphone' in key:
        cellphone_number = val
        
    if 'institution' in key:
        institution = val
        
    if 'department' in key:
        department = val
        
    if 'email' in key:
        email = val

    if 'general objective' in key:
        if once2 == False:
            general_objective = val
            once2 = True

    if 'specific objective' in key:
        if once3 == False:
            specific_objective = val
            once3 = True
        
    if 'methodology' in key:
                
        methodology = val
        
    if 'operational definition' in key:
        
        operational_definitions = str(val)
        
    if 'inclusion criteria' in key:
        inclusion_criteria = val
        
    if 'exclusion criteria' in key:
        exclusion_criteria = val
        
    if 'data sources' in key:
        data_sources_and_data_collection_and_quality_assurance = val

        
    if 'statistical plan' in key:
        statistical_plan_of_analysis = val

        
    if 'data collection tool' in key:
        data_collection_tool = val

        
    if 'budget' in key:
        budget = val

        
    if 'timeline' in key:
        timeline = val


    if 'proposed specific objective' in key:
        proposed_specific_objective = val
        
    if 'proposed general objective' in key:
        proposed_general_objective = val
        
    if 'proposed introduction' in key:
        proposed_introduction = val   

    if 'proposed title' in key:
        proposed_title = val  
        
    if 'background' in key:
        if background == '':
            background = val
        
    if 'null hypothesis' in key:
        null_hypotheses = val
        
    if 'alternative hypothesis' in key:
        alternative_hypotheses = val
        
    if 'related literature' in key:
        related_literature = val
        
    if 'ethical considerations' in key:
        ethical_considerations = val
    
    if 'community consideration' in key:
        community_consideration = val

# %%
ethical_considerations

# %%
temp = ''
uu = 1
for i in proposed_specific_objective.split("'"):
    if len(i) > 5:
        temp += str(uu) + '.) ' + i + '\n'
        uu += 1
proposed_specific_objective  = temp
proposed_specific_objective

# %%
temp = ''
uu = 1
for i in specific_objective.split("\n"):
    if len(i) > 5:
        temp += str(uu) + '.) ' + i + '\n'
        uu += 1
specific_objective  = temp
specific_objective

# %%
# specific_objective = specific_objective.replace('\n','\n\t')
# proposed_specific_objective = proposed_specific_objective.replace('\n','\n\t')

# %%
if str(department).strip() == 'nan':
    department = ''
if str(cellphone_number).strip() == 'nan':
    cellphone_number = ''
if str(email).strip() ==  'nan':
    email = ''

# %%
cellphone_number = str(cellphone_number)

# %%
x = datetime.datetime.now()

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Date: ' + str(x.day) + ' ' + calendar.month_name[x.month] + ' ' + str(x.year)

run.font.name = 'Arial'
run.font.size = Pt(12)


table = doc.add_table(rows=1, cols=2)
table.style = 'Table Grid'
row = table.rows[0].cells


row[0].text = 'Author'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = author
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

data = (
('Department', department),
('Institution', institution),
('Research title', research_title),
('Email', email),
('Cellphone Number', cellphone_number)
)

for id_, name in data:
    name = str(name)
    row = table.add_row().cells
    row[0].text = str(id_)
    row[0].paragraphs[0].runs[0].font.name = 'Arial'
    row[0].paragraphs[0].runs[0].font.size = Pt(12)
    row[0].paragraphs[0].runs[0].font.bold = True

    row[1].text = name    
    row[1].paragraphs[0].runs[0].font.name = 'Arial'
    row[1].paragraphs[0].runs[0].font.size = Pt(12)    

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Document History'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)

table = doc.add_table(rows=2, cols=3)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Version'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

row[1].text = 'Date'
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

row[2].text = 'Remarks'
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)

row = table.rows[1].cells

row[0].text = 'V1'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

date_updated = str(x.day) + ' ' + calendar.month_name[x.month] + ' ' + str(x.year)
row[1].text = 'Updated ' + date_updated
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

row[2].text = 'Initial Version ' 
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)


doc.add_page_break() 
p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Contents'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)

# %%
## Table of Contents 
paragraph = doc.add_paragraph()
run = paragraph.add_run()

fldChar = OxmlElement('w:fldChar')  # creates a new element
fldChar.set(qn('w:fldCharType'), 'begin')  # sets attribute on element

instrText = OxmlElement('w:instrText')
instrText.set(qn('xml:space'), 'preserve')  # sets attribute on element
instrText.text = 'TOC \\o "1-3" \\h \\z \\u'   # change 1-3 depending on heading levels you need

fldChar2 = OxmlElement('w:fldChar')
fldChar2.set(qn('w:fldCharType'), 'separate')

fldChar3 = OxmlElement('w:t')
fldChar3.text = "Right-click to update field."

fldChar2.append(fldChar3)

fldChar4 = OxmlElement('w:fldChar')
fldChar4.set(qn('w:fldCharType'), 'end')

r_element = run._r
r_element.append(fldChar)
r_element.append(instrText)
r_element.append(fldChar2)
r_element.append(fldChar4)

p_element = paragraph._p

# %%
background = background.replace('\t','')
related_literature = related_literature.replace('\t','')

# %%
background

# %%
######

# Giving headings that need to be included in Table of contents
doc.add_page_break() 

### TITLE
p = doc.add_heading('')
run = p.add_run()
run.text = '1. Title'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=2, cols=2)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Working study title'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = 'Proposed title/ comments'
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)
row[1].paragraphs[0].runs[0].font.bold = True


row = table.rows[1].cells

row[0].text =  '\n' + research_title
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

row[1].text = '\n' + proposed_title
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)





p = doc.add_heading('')
run = p.add_run()
run.text = "2. Background and Related Literature"
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=1, cols=1)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text =  'Background' +  '\n\n' + background + '\n\n' + 'Related Literature'+ '\n'  + related_literature
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
# row[0].paragraphs[0].alignment = docx.enum.text.WD_ALIGN_PARAGRAPH.JUSTIFY


p = doc.add_heading('')
run = p.add_run()
run.text = '3. Research Objectives'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=3, cols=2)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Current objectives'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True


row[1].text = "Proposed re-phrasing of objectives/ Comments or clarifications"
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)
row[1].paragraphs[0].runs[0].font.bold = True



row = table.rows[1].cells

row[0].text =  'General Objective ' + '\n\n' + general_objective
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)


row[1].text = 'Proposed General Objective ' + '\n\n' + proposed_general_objective
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)


row = table.rows[2].cells

row[0].text =  'Specific Objective ' + '\n\n' + specific_objective
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)



row[1].text = 'Proposed Specific Objective ' + '\n\n' + proposed_specific_objective
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)




p = doc.add_heading('')
run = p.add_run()
run.text = '4. Hypothesis'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=2, cols=2)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Null'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = '\n' + null_hypotheses
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)



row = table.rows[1].cells

row[0].text =  "Alternative"
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text =  alternative_hypotheses
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

# %%
### For Elements
lst_elements = []
lst_specifics = []
for i in list(df['Keys']):
    if 'element' in i:
        print(i.split(':')[1].strip())
        print(df[df['Keys']==i]['Values'].iloc[0])
        lst_elements.append(i.split(':')[1].strip())
        lst_specifics.append(df[df['Keys']==i]['Values'].iloc[0])
        print()

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '5. Methods'
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

p = doc.add_heading('')
run = p.add_run()
run.text = '   5.1. Research question elements'
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=len(lst_elements)+1, cols=3)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Element'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = 'Specify'
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)
row[1].paragraphs[0].runs[0].font.bold = True

row[2].text = 'Comment'
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)
row[2].paragraphs[0].runs[0].font.bold = True

i = 1
for element,specify in zip(lst_elements,lst_specifics):
    row = table.rows[i].cells
    
    row[0].text = element
    row[0].paragraphs[0].runs[0].font.name = 'Arial'
    row[0].paragraphs[0].runs[0].font.size = Pt(12)


    row[1].text = specify
    row[1].paragraphs[0].runs[0].font.name = 'Arial'
    row[1].paragraphs[0].runs[0].font.size = Pt(12)


    row[2].text = ''
    row[2].paragraphs[0].runs[0].font.name = 'Arial'
    row[2].paragraphs[0].runs[0].font.size = Pt(12)
    
    i += 1

# %%
df.columns

# %%
dct_category = {}
for i,u in zip(list(df['Keys']), list(df['Values'])) :
    if 'category' in i:
        cat = ' '.join(i.split(' ')[1:]).lower().strip()
        val = u
        dct_category[cat] = val
        print(cat, val)

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.2. Study design classification'
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=3, cols=4)
table.style = 'Table Grid'

row0 = table.rows[0].cells
row1 = table.rows[1].cells
row2 = table.rows[2].cells

cell1 = row0[3].merge(row1[3])
cell2 = row1[0].merge(row1[1]).merge(row1[2])
cell3 = row2[0].merge(row2[1]).merge(row2[2]).merge(row2[3])

row0[0].text = 'Temporality: ' + '\n' + dct_category['temporality']
row0[0].paragraphs[0].runs[0].font.name = 'Arial'
row0[0].paragraphs[0].runs[0].font.size = Pt(12)
row0[0].paragraphs[0].runs[0].font.bold = True

row0[1].text = 'Level of analysis: ' + '\n' + dct_category['level of analysis']
row0[1].paragraphs[0].runs[0].font.name = 'Arial'
row0[1].paragraphs[0].runs[0].font.size = Pt(12)
row0[1].paragraphs[0].runs[0].font.bold = True

row0[2].text = 'Level of intervention: ' + '\n' + dct_category['level of intervention']
row0[2].paragraphs[0].runs[0].font.name = 'Arial'
row0[2].paragraphs[0].runs[0].font.size = Pt(12)
row0[2].paragraphs[0].runs[0].font.bold = True

cell1.text = 'Specific study type: '  + '\n' + dct_category['specific study type']
cell1.paragraphs[0].runs[0].font.name = 'Arial'
cell1.paragraphs[0].runs[0].font.size = Pt(12)
cell1.paragraphs[0].runs[0].font.bold = True



cell2.text = 'Category: ' + '\n' + dct_category['category']
cell2.paragraphs[0].runs[0].font.name = 'Arial'
cell2.paragraphs[0].runs[0].font.size = Pt(12)
cell2.paragraphs[0].runs[0].font.bold = True


cell3.text = 'General Comments'
cell3.paragraphs[0].runs[0].font.name = 'Arial'
cell3.paragraphs[0].runs[0].font.size = Pt(12)
cell3.paragraphs[0].runs[0].font.bold = True

# %%
for i in df['Keys']:
    print(i)

# %%
df[df['Keys'] == 'operational_definitions']['Values']

# %%
operational_definitions = df[df['Keys'] == 'operational_definitions']['Values'].iloc[0]
procedures = df[df['Keys'] == 'procedures']['Values'].iloc[0]

# %%
procedures

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.3. Operational definitions, procedures, process of withdrawal '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=3, cols=2)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Operational definitions'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = operational_definitions
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)


row = table.rows[1].cells

row[0].text = 'Procedures'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = procedures
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

row = table.rows[2].cells

row[0].text = 'Process of withdrawal'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = process_withdrawal
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)

# %%
for i in df['Keys']:
    print(i)

# %%
# name_of_outcomes 0
# name_of_outcomes 1
# name_of_outcomes 2
# name_of_outcomes 3
# name_of_outcomes 4
# name_of_outcomes 5
# metric/measurement 0
# metric/measurement 1
# metric/measurement 2
# metric/measurement 3
# metric/measurement 4
# metric/measurement 5
# time_endpoints 0
# time_endpoints 1
# time_endpoints 2
# time_endpoints 3
# time_endpoints 4
# time_endpoints 5
lst_outcomes = []
for i in df['Keys']:
    if 'name of outcome' in i.lower():
        val =df[df['Keys'] == i]['Values'].iloc[0]
        lst_outcomes.append(val)
lst_metric = []
for i in df['Keys']:
    if 'metric/measurement' in i.lower():
        val =df[df['Keys'] == i]['Values'].iloc[0]
        lst_metric.append(val)
lst_time = []
for i in df['Keys']:
    if 'time endpoints' in i.lower():
        val =df[df['Keys'] == i]['Values'].iloc[0]
        lst_time.append(val)

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.4. Outcome/s of interest '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


table = doc.add_table(rows=len(lst_outcomes)+1, cols=4)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Name of outcome'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = 'Metric/measurement '
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)
row[1].paragraphs[0].runs[0].font.bold = True

row[2].text = 'Time endpoints'
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)
row[2].paragraphs[0].runs[0].font.bold = True

row[3].text = 'Interpretation'
row[3].paragraphs[0].runs[0].font.name = 'Arial'
row[3].paragraphs[0].runs[0].font.size = Pt(12)
row[3].paragraphs[0].runs[0].font.bold = True

ii = 1
for i,u,o in zip(lst_outcomes,lst_metric, lst_time):
    
    row = table.rows[ii].cells

    row[0].text = i
    row[0].paragraphs[0].runs[0].font.name = 'Arial'
    row[0].paragraphs[0].runs[0].font.size = Pt(12)


    row[1].text = u
    row[1].paragraphs[0].runs[0].font.name = 'Arial'
    row[1].paragraphs[0].runs[0].font.size = Pt(12)


    row[2].text = o
    row[2].paragraphs[0].runs[0].font.name = 'Arial'
    row[2].paragraphs[0].runs[0].font.size = Pt(12)


    row[3].text = ' '
    row[3].paragraphs[0].runs[0].font.name = 'Arial'
    row[3].paragraphs[0].runs[0].font.size = Pt(12)

    
    
    
    ii += 1

# %%
for i in df['Keys']:
    if 'exposures' in i.lower():
        val = df[df['Keys'] == i]['Values'].iloc[0]
        print(i, val)
        exposures = val
    if 'confounders' in i.lower():
        val = df[df['Keys'] == i]['Values'].iloc[0]
        print(i,val)
        confounders = val
    if 'effect_modifiers' in i.lower():
        val = df[df['Keys'] == i]['Values'].iloc[0]
        print(i,val)
        effect_modifiers = val

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.5. Exposures, confounders, effect modifiers '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=2, cols=3)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = 'Exposures'
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
row[0].paragraphs[0].runs[0].font.bold = True

row[1].text = 'Cofounders'
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)
row[1].paragraphs[0].runs[0].font.bold = True

row[2].text = 'Effect Modifiers'
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)
row[2].paragraphs[0].runs[0].font.bold = True

row = table.rows[1].cells

row[0].text = exposures
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

row[1].text = confounders
row[1].paragraphs[0].runs[0].font.name = 'Arial'
row[1].paragraphs[0].runs[0].font.size = Pt(12)


row[2].text = effect_modifiers 
row[2].paragraphs[0].runs[0].font.name = 'Arial'
row[2].paragraphs[0].runs[0].font.size = Pt(12)

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.6. Sample size calculation '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00)

# %%
for i in df['Keys']:
    if 'sampling methods' in i:
        sampling_methods =  df[df['Keys'] == i]['Values'].iloc[0]

# %%
sampling_methods

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.7. Data Collection '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

p = doc.add_heading('')
run = p.add_run()
run.text = '      5.7.1. Sampling methods and randominization '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=1, cols=1)
table.style = 'Table Grid'

row = table.rows[0].cells

row[0].text = sampling_methods
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

# %%
for i in df['Keys']:
    if 'blinding' in i:
        blinding =  df[df['Keys'] == i]['Values'].iloc[0]

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '      5.7.2. Blinding '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=1, cols=1)
table.style = 'Table Grid'
row = table.rows[0].cells

row[0].text = blinding
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '      5.7.3. Data management, archiving, and confidentiality  '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=1, cols=1)
table.style = 'Table Grid'

row = table.rows[0].cells


content = "Subject information will be kept in a secure office, with access available only to members of the research team. Computerized study information will be stored on secured network with password access. All identifiable information and data will be given a code number. A master list linking the code number and subject identity will be kept separately from the research data. Only members of the research team will have access to the list. The research records will be stored for at least three years following completion of the study. Individually identifiable research data will not be shared with others outside of the research and analysis team. The investigator and all key personnel will have completed the Good Clinical Practice (GCP) training on the responsible conduct of research with human data. "

row[0].text = content
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)

p = doc.add_heading('')
run = p.add_run()
run.text = '   5.8. Plan of analysis '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


p = doc.add_heading('')
run = p.add_run()
run.text = '   5.9. Reporting of adverse events  '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

table = doc.add_table(rows=1, cols=1)
table.style = 'Table Grid'

row = table.rows[0].cells

first_paragraph = '1. Documentation'  + '\n' + '- Comprehensively document nature of the event, date and time of occurrence, severity, duration, any associated symptoms or complications, and the individual(s) affected '
second_paragraph = '2. Classification and Grading' + '\n' + '-should be classified and graded based on their severity and potential impact using a predetermined classification and grading system '
third_paragraph = '3. Confidentiality and privacy' + '\n' + '-maintain confidentiality and privacy by using participant identifiers only for internal communication among authorized individuals involved in the study. Avoid sharing identifiable information in any public or unsecured communication channels.' 
                   
content = first_paragraph + '\n\n' + second_paragraph + '\n\n' + third_paragraph

row[0].text = content
row[0].paragraphs[0].runs[0].font.name = 'Arial'
row[0].paragraphs[0].runs[0].font.size = Pt(12)
# row[0].paragraphs[0].alignment = docx.enum.text.WD_ALIGN_PARAGRAPH.JUSTIFY

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = '   5.10. Dummy tables and figures  '
run.font.bold = True

run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00)

# %%
for i in df['Keys']:
    if 'Dummy Table' in i:
        val =  df[df['Keys'] == i]['Values'].iloc[0]

        title = i.replace('Dummy','')
#         print(title)

        num_rows = 0
        lst_all = []
        for u in val.split('\n'):
            u = u.strip()
            if len(u) > 5:
                lst_ = []
                if u:
                    num_cols = 0
                    for uu in u.split('**'):
                        if uu:
                            num_cols += 1
#                             print(uu)
                            lst_.append(uu)
                lst_all.append(lst_)
                num_rows += 1

        p = doc.add_heading('')         
        run = p.add_run()
        run.text = title
        run.font.bold = True

        run.font.name = 'Arial'
        run.font.size = Pt(12)
        run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 
       
        
        table = doc.add_table(rows=num_rows, cols=num_cols)
        table.style = 'Table Grid'
        
        for i in range(num_rows):
            
            row = table.rows[i].cells
            row_values = lst_all[i]
            for u in range(num_cols):
                row[u].text = row_values[u]
                row[u].paragraphs[0].runs[0].font.name = 'Arial'
                row[u].paragraphs[0].runs[0].font.size = Pt(10)

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = "6. Data collection tool"
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00)

# %%
for i in df['Keys']:
    if 'data collection table' ==  i:
        val =  df[df['Keys'] == i]['Values'].iloc[0]
        
        num_rows = 0
        lst_all = []
        for u in val.split('****'):
            u = u.strip()
            if len(u) > 5:
                lst_ = []
                if u:
                    num_cols = 0
                    for uu in u.split('**'):
                        if uu:
                            num_cols += 1
#                             print(uu)
                            lst_.append(uu)
                lst_all.append(lst_)
                num_rows += 1        

        p = doc.add_heading('')         
        run = p.add_run()
        run.font.name = 'Arial'
        run.font.size = Pt(12)
        run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 
       
        
        table = doc.add_table(rows=num_rows, cols=num_cols)
        table.style = 'Table Grid'
        
        for i in range(num_rows):
            
            row = table.rows[i].cells
            row_values = lst_all[i]
            for u in range(num_cols):
                row[u].text = row_values[u]
                row[u].paragraphs[0].runs[0].font.name = 'Arial'
                row[u].paragraphs[0].runs[0].font.size = Pt(8)
                
                
        print(num_rows,num_cols)

# %%
description = df[df['Keys'] == 'data collection table description']['Values'].iloc[0]
p = doc.add_heading('')
run = p.add_run()
run.text = description
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 
run.font.bold = False

# %%
p = doc.add_heading('')
run = p.add_run()
run.text = "7. Ethical considerations"
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 


first_paragraph  = ethical_considerations + '.' 
second_paragraph = 'The protocol of this study adheres to the ethical considerations and ethical principles set out in relevant guidelines, including the Declaration of Helsinki, WHO guidelines, International Conference on Harmonization-Good Clinical Practice, Data Privacy Act of 2012, and the National Ethics Guidelines for Health Research. '

content = first_paragraph + '\n\n' + second_paragraph

p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Conflicts of Interest and Funding '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

content = "The principal investigators and co-investigators declare no potential conflicts of interest or financial disclosures that could affect the study's integrity. No external funding or study grants have been obtained for this research, ensuring its independence from any financial influences. "
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Data safety, privacy, and confidentiality '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

content = "The research team will take stringent measures to protect participants' information. Physical records will be securely stored, with access limited to authorized team members. Digital data will be kept on a password-protected network, and personal identifiers will be replaced with code numbers. A master list linking code numbers to participant identities will be stored separately from research data and accessed only by authorized team members. Research records will be retained for at least five years after study completion, and identifiable data will not be shared outside the research and analysis team. "
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

content = "All key personnel will complete Good Clinical Practice (GCP) training on responsible research conduct with human data. The primary investigator will oversee study monitoring and adverse event reporting, while data monitors from the Nursing Research Committee will provide independent cross-validation and ensure proper informed consent and adverse event documentation. Data monitoring will be conducted continuously throughout the study. "
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

content = "When sharing study results through conferences, publications, or other venues, participant anonymity will be maintained by presenting only analyzed data without individual identifiers. "
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'IRB approval and informed consent '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

content = 'The study will only commence upon the approval of the Institutional Review Board of the AFP Medical Center. The data shall be collected through a chart review, precluding informed consent. '
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Vulnerability  '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

content = 'We recognize that our subjects are particularly vulnerable, and we will take extra care in the confidentiality of their identities. Moreover, this is a retrospective study. '
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Vulnerability and Recruitment'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True


content = 'As the study will involve vulnerable patients from the NKTI HD outpatient (annex and modular unit) and participating dialysis centers within 2 kilometers of NKTI, extra care will be taken when obtaining informed consent, ensuring that participants are not in distress and fully understand their right to refuse or withdraw from the study at any time. Recruitment will begin only after receiving clearance from the ​NKTI​ and permission from the Department of Adult Nephrology. Inclusion and exclusion criteria will be strictly followed, and the sample population will consist of voluntary participants from the NKTI HD outpatient (annex and modular unit) and participating dialysis centers within 2 kilometers of NKTI. '
p = doc.add_paragraph('')
run = p.add_run()
run.text = content
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Adverse events or risks'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'No adverse events are anticipated,because this is a study to be conducted retrospectively.'
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Adverse events or risks'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

first = 'Respondents may experience discomfort due to the time required to participate in an interview. In case of a medical emergency, the research team will promptly initiate the following Emergency Response Plan: '
second = '\n   1. Assess the situation and call for immediate medical assistance if necessary. '
third = "\n   2. Provide first aid or initial intervention within the research team's scope of practice and competence. "
fourth = "\n   3. Notify the participant's primary healthcare provider, if applicable and appropriate. "
fifth = "\n   4. Document the incident and report it to the principal investigator and Institutional Review Board (IRB) as required. "
sixth = "\n   5. Adjust or modify the study protocol, if necessary, to minimize the risk of similar incidents in the future. "
seventh = "\n\nAll serious adverse events will be reported to the IRB within 24 hours, and other adverse events within three days. Any serious adverse event associated with the study protocol will result in the participant's immediate withdrawal. "


p = doc.add_paragraph('')
run = p.add_run()
run.text = first + second + third + fourth + fifth + sixth + seventh 
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Discontinuation'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Not applicable, because this is a study to be conducted retrospectively.'
run.font.name = 'Arial'
run.font.size = Pt(12)



p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Community Consideration'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True


p = doc.add_paragraph('')
run = p.add_run()
run.text = community_consideration + '.'
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Compensation'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'This study is initiated and funded wholly by the principal investigator. As this is a retrospective study, no compensation is to be given to patients who are part of the analysis. '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Benefit'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'The results and analysis from this study has potential societal benefits, which will directly or indirectly benefit the participants through health systems delivery strengthening or improvements in implementation or policy change. '
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Funding'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.underline = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'This study is not under any study grant nor has received any support from any external funding agencies.'
run.font.name = 'Arial'
run.font.size = Pt(12)



p = doc.add_heading('')
run = p.add_run()
run.text = "8. Information Sheet and Consent Form "
run.font.bold = True
run.font.underline = True
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.color.rgb = RGBColor(0x00, 0x00, 0x00) 

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Instructions for Information Sheet and Consent Form (English) '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Project Title: ' 
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

run = p.add_run()
run.text = research_title
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()
              
p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Principal Investigator: '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True


run = p.add_run()
run.text =   author + ', MD'
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = '                                      ' + department
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = '                                      ' + str(institution)
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()
              
p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Contact details: '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

run = p.add_run()
run.text =   cellphone_number + '/ ' + email
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   1. What is the purpose of this study?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   This study aims to '
run.font.name = 'Arial'
run.font.size = Pt(12)


run = p.add_run()
run.text = general_objective
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   2. Who is eligible to participate, and what is the expected duration of participation?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   To participate in this study, individuals must be: '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = inclusion_criteria
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()
              
p = doc.add_paragraph('')
run = p.add_run()
run.text = '   We are exluding: '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = exclusion_criteria
run.font.name = 'Arial'
run.font.size = Pt(12)




p = doc.add_paragraph('')
run = p.add_run()
run.text = "The study will involve approximately " + str(number_patients) + " patients. Participation in the study will take about " + str(duration) + " to complete. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   3. What will happen if I participate in this study?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "Upon providing written informed consent, you will be asked to participate in an interview. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   4. How will my privacy and the confidentiality of my research records be protected?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "Your privacy and the confidentiality of your research records will be protected. Each participant will be assigned a unique identifier code, ensuring that your name does not appear on any records. Only the research team will have access to the hard and soft copies of the records, which will not be released to other interest groups or the public. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   5. What are the potential discomforts and risks of participating in the study?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "The risk of discomfort is minimal, as you will only be asked to participate in an interview. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   6. What compensation will be provided for any injury?'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "Injuries are highly unlikely to occur as you will only participate in an interview. "
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   7. Will there be reimbursement for participation? '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "No monetary compensation will be provided for participating in the study. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   8. What are the possible benefits to me and others? '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "The knowledge gained from this study may benefit future patients, medical practitioners, and hospital administration by helping improve the management of patients with conditions similar to yours. The results may also provide supporting evidence for doctors when making objective treatment decisions for " +disease + " patients. "
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   9. Can I refuse to participate or withdraw from the study?  '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "Participation in this study is entirely voluntary. You have the right to withdraw from the study at any time, as long as the study results are not yet final, without any negative consequences for your medical care or relationship with the researchers. "
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   10. Whom should I contact if I have any questions or concerns?  '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = "For any concerns or questions, please contact the Principal Investigator, " + author + ", at phone number/email for research-related matters. For an independent opinion on the study, you may contact [" + author + " , "+ cellphone_number + ", " + email + " of the " + str(institution) + " Institutional Review Board. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()



p = doc.add_paragraph('')
run = p.add_run()
run.text = "Thank you very much in advance for your interest and assistance with this research. "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = "Sincerely,  "
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = author + ", MD"
run.font.name = 'Arial'
run.font.size = Pt(12)

doc.add_page_break() 

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Instructions for Information Sheet and Consent Form (English) '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True
run.font.underline = True

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Project Title'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True

run = p.add_run()
run.text = research_title
run.font.name = 'Arial'
run.font.size = Pt(12)

              
p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Principal Investigator: '
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True


run = p.add_run()
run.text =   author + ', MD'
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = '                                      ' + department
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = '                                      ' + str(institution)
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()


p = doc.add_paragraph('')
run = p.add_run()
run.text = 'Contact Details'
run.font.name = 'Arial'
run.font.size = Pt(12)
run.font.bold = True


run = p.add_run()
run.text =   cellphone_number + '/ ' + email
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'I hereby acknowledge that: '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   1. My signature is my acknowledgement that I have agreed to take part in the above research. '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.text = '   2. I have received a copy of this information sheet that explains the use of my data in this research. I understand its contents and agree to donate my data for the use of this research. '
run.font.name = 'Arial'
run.font.size = Pt(12)


p = doc.add_paragraph('')
run = p.add_run()
run.text = '   3. I can withdraw from the research at any point of time by informing the Principal Investigator and all my data will be discarded. '
run.font.name = 'Arial'
run.font.size = Pt(12)

p = doc.add_paragraph('')
run = p.add_run()
run.add_break()

p = doc.add_paragraph('')
run = p.add_run()
run.text = 'This research has been explained to me in English, which I understand, by ___________________ [NAME OF TRANSLATOR] on ________________ [DATE] '
run.font.name = 'Arial'
run.font.size = Pt(12)

doc.add_page_break()

# %%
import datetime;
 
# ct stores current time
ct = datetime.datetime.now()

ct = str(ct).replace(':','')
ct = ct.replace('.','')
ct = ct.replace(' ','')
file_name = str(ct) + '_RPA_.docx'
doc.save(file_name)
